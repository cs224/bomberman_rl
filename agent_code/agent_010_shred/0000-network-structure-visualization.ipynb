# %%
# %load_ext watermark
# %watermark -a 'Christian Schuhegger' -u -d -v -p numpy,scipy,pandas,matplotlib,h5py,mxnet,xarray
# Out:
# Christian Schuhegger
# last updated: 2019-03-12
#
# CPython 3.6.8
# IPython 7.3.0
#
# numpy 1.15.4
# scipy 1.2.1
# pandas 0.24.1
# matplotlib 3.0.2
# h5py 2.9.0
# mxnet 1.3.1
# xarray 0.11.3

# %%
import os,sys
sys.path.append(os.path.realpath('.'))
sys.path.append(os.path.realpath('../../'))

# %%
# %matplotlib inline
import numpy as np, scipy.stats as stats, pandas as pd, xarray as xr, matplotlib.pyplot as plt, seaborn as sns
import logging
# import sklearn, sklearn.pipeline, sklearn.model_selection, sklearn.preprocessing
# import logging, time, datetime
# from settings import s, e
import mxnet as mx
# import tqdm

pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
# pd.set_option('display.float_format', lambda x: '%.2f' % x)
np.set_printoptions(edgeitems=10)
np.set_printoptions(linewidth=1000)
np.set_printoptions(suppress=True)
np.core.arrayprint._line_width = 180

sns.set()

# %%
from IPython.display import display, HTML

from IPython.display import display_html
def display_side_by_side(*args):
    html_str=''
    for df in args:
        if type(df) == np.ndarray:
            df = pd.DataFrame(df)
        html_str+=df.to_html()
    html_str = html_str.replace('table','table style="display:inline"')
    # print(html_str)
    display_html(html_str,raw=True)

CSS = """
.output {
    flex-direction: row;
}
"""

def display_graphs_side_by_side(*args):
    html_str='<table><tr>'
    for g in args:
        html_str += '<td>'
        html_str += g._repr_svg_()
        html_str += '</td>'
    html_str += '</tr></table>'
    display_html(html_str,raw=True)
    

display(HTML("<style>.container { width:70% !important; }</style>"))
# Out:
# <style>.container { width:70% !important; }</style>

# %%
#from .model.model_base_mx import VGGPlusModel
from model.model_base_mx import VGGPlusModel
# Out:
# pygame 1.9.4
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s:%(name)s:%(levelname)s: %(message)s')
log = logging.getLogger('std')

# %%
model = VGGPlusModel(log)
# Out:
# 2019-03-12 07:12:20,547:std:DEBUG: setup
# 2019-03-12 07:12:20,548:std:DEBUG: setup
# 2019-03-12 07:12:20,564:std:INFO: number of gpus: 1, ctx: gpu(0)
# 2019-03-12 07:12:20,565:model_base_mx:DEBUG: model_ctx    : gpu(0)
# 2019-03-12 07:12:20,566:model_base_mx:DEBUG: VGGPlusBlock start
# 2019-03-12 07:12:20,566:model_base_mx:DEBUG: VGGPlusBlock._make_features
# 2019-03-12 07:12:20,567:model_base_mx:DEBUG: l: Conv2D(None -> 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 2019-03-12 07:12:20,569:model_base_mx:DEBUG: l: Conv2D(None -> 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 2019-03-12 07:12:20,571:model_base_mx:DEBUG: l: Conv2D(None -> 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 2019-03-12 07:12:20,572:model_base_mx:DEBUG: l: Conv2D(None -> 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 2019-03-12 07:12:20,573:model_base_mx:DEBUG: VGGPlusBlock._make_features
# 2019-03-12 07:12:20,574:model_base_mx:DEBUG: l: Conv2D(None -> 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 2019-03-12 07:12:20,576:model_base_mx:DEBUG: l: Conv2D(None -> 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 2019-03-12 07:12:20,577:model_base_mx:DEBUG: l: Conv2D(None -> 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 2019-03-12 07:12:20,578:model_base_mx:DEBUG: VGGPlusBlock end
# 2019-03-12 07:12:22,072:model_base_mx:DEBUG: OS           : linux
# 2019-03-12 07:12:22,073:model_base_mx:DEBUG: Python       : 3.6.8 |Anaconda, Inc.| (default, Dec 30 2018, 01:22:34)
# [GCC 7.3.0]
# 2019-03-12 07:12:22,073:model_base_mx:DEBUG: MXNet        : 1.3.1
# 2019-03-12 07:12:22,074:model_base_mx:DEBUG: Numpy        : 1.15.4
# 2019-03-12 07:12:22,126:model_base_mx:DEBUG: GPU          : ['GeForce GTX 1080']
# 2019-03-12 07:12:22,127:model_base_mx:DEBUG: CPU cores    : 12
# 2019-03-12 07:12:22,128:model_base_mx:DEBUG: CUDA Version 9.0.176
# 2019-03-12 07:12:22,130:model_base_mx:DEBUG: CuDNN Version: 7.4.2

# %%
x1 = mx.sym.var('data0')
x2 = mx.sym.var('data1')
sym = model.model(x1,x2)
mx.visualization.print_summary(sym,  shape={'data0':(593552, 22), 'data1': (593552, 7, 11, 11)}, line_length=280)
# Out:
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# Layer (type)                                                                                                               Output Shape                                            Param #                     Previous Layer
# ========================================================================================================================================================================================================================================================================================
# data0(null)                                                                                                                22                                                      0
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# vggplusblock0_f1conv0_fwd(Convolution)                                                                                     32x11x11                                                32
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# vggplusblock0_f1batchnorm0_fwd(BatchNorm)                                                                                  32x11x11                                                64                          vggplusblock0_f1conv0_fwd
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# vggplusblock0_f1relu0_fwd(Activation)                                                                                      32x11x11                                                0                           vggplusblock0_f1batchnorm0_fwd
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# vggplusblock0_f1conv1_fwd(Convolution)                                                                                     32x11x11                                                9248                        vggplusblock0_f1relu0_fwd
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# vggplusblock0_f1batchnorm1_fwd(BatchNorm)                                                                                  32x11x11                                                64                          vggplusblock0_f1conv1_fwd
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# vggplusblock0_f1relu1_fwd(Activation)                                                                                      32x11x11                                                0                           vggplusblock0_f1batchnorm1_fwd
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# vggplusblock0_f1conv2_fwd(Convolution)                                                                                     32x11x11                                                9248                        vggplusblock0_f1relu1_fwd
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# vggplusblock0_f1batchnorm2_fwd(BatchNorm)                                                                                  32x11x11                                                64                          vggplusblock0_f1conv2_fwd
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# vggplusblock0_f1relu2_fwd(Activation)                                                                                      32x11x11                                                0                           vggplusblock0_f1batchnorm2_fwd
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# vggplusblock0_f1conv3_fwd(Convolution)                                                                                     32x11x11                                                9248                        vggplusblock0_f1relu2_fwd
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# vggplusblock0_f1batchnorm3_fwd(BatchNorm)                                                                                  32x11x11                                                64                          vggplusblock0_f1conv3_fwd
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# vggplusblock0_f1relu3_fwd(Activation)                                                                                      32x11x11                                                0                           vggplusblock0_f1batchnorm3_fwd
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# vggplusblock0_f1pool0_fwd(Pooling)                                                                                         32x6x6                                                  0                           vggplusblock0_f1relu3_fwd
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# vggplusblock0_f2conv0_fwd(Convolution)                                                                                     64x6x6                                                  18496                       vggplusblock0_f1pool0_fwd
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# vggplusblock0_f2batchnorm0_fwd(BatchNorm)                                                                                  64x6x6                                                  128                         vggplusblock0_f2conv0_fwd
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# vggplusblock0_f2relu0_fwd(Activation)                                                                                      64x6x6                                                  0                           vggplusblock0_f2batchnorm0_fwd
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# vggplusblock0_f2conv1_fwd(Convolution)                                                                                     64x6x6                                                  36928                       vggplusblock0_f2relu0_fwd
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# vggplusblock0_f2batchnorm1_fwd(BatchNorm)                                                                                  64x6x6                                                  128                         vggplusblock0_f2conv1_fwd
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# vggplusblock0_f2relu1_fwd(Activation)                                                                                      64x6x6                                                  0                           vggplusblock0_f2batchnorm1_fwd
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# vggplusblock0_f2conv2_fwd(Convolution)                                                                                     64x6x6                                                  36928                       vggplusblock0_f2relu1_fwd
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# vggplusblock0_f2batchnorm2_fwd(BatchNorm)                                                                                  64x6x6                                                  128                         vggplusblock0_f2conv2_fwd
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# vggplusblock0_f2relu2_fwd(Activation)                                                                                      64x6x6                                                  0                           vggplusblock0_f2batchnorm2_fwd
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# vggplusblock0_f2pool0_fwd(Pooling)                                                                                         64x3x3                                                  0                           vggplusblock0_f2relu2_fwd
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# vggplusblock0_flatten0_flatten0(Flatten)                                                                                   576                                                     0                           vggplusblock0_f2pool0_fwd
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# vggplusblock0_concat0(Concat)                                                                                              598                                                     0                           data0
#                                                                                                                                                                                                                vggplusblock0_flatten0_flatten0
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# vggplusblock0_fc-1fwd(FullyConnected)                                                                                      512                                                     306688                      vggplusblock0_concat0
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# vggplusblock0_fc-1relu_fwd(Activation)                                                                                     512                                                     0                           vggplusblock0_fc-1fwd
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# vggplusblock0_dropout0_fwd(Dropout)                                                                                        512                                                     0                           vggplusblock0_fc-1relu_fwd
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# vggplusblock0_fc-2fwd(FullyConnected)                                                                                      512                                                     262656                      vggplusblock0_dropout0_fwd
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# vggplusblock0_fc-2relu_fwd(Activation)                                                                                     512                                                     0                           vggplusblock0_fc-2fwd
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# vggplusblock0_dropout1_fwd(Dropout)                                                                                        512                                                     0                           vggplusblock0_fc-2relu_fwd
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# vggplusblock0_predictionsfwd(FullyConnected)                                                                               1                                                       513                         vggplusblock0_dropout1_fwd
# ========================================================================================================================================================================================================================================================================================
# Total params: 690625
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %%
digraph = mx.viz.plot_network(sym, shape={'data0':(593552, 22), 'data1': (593552, 7, 11, 11)}, node_attrs={"fixedsize":"false"})
#digraph.view() # will create 'plot.gv.pdf'
digraph
